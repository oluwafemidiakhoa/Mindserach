# %% [markdown]
# <a href="https://colab.research.google.com/github/oluwafemidiakhoa/Mindserach/blob/master/Earthmonitoring.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install requests geopandas shapely pandas rasterio matplotlib scikit-learn networkx folium
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (0.14.4)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (2.0.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Collecting rasterio
#   Downloading rasterio-1.3.10-cp310-cp310-manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.3.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.3)
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.7.4)
# Requirement already satisfied: fiona>=1.8.21 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.9.6)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (24.1)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (24.2.0)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Collecting snuggs>=1.4.1 (from rasterio)
#   Downloading snuggs-1.4.7-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio) (71.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.4)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.10/dist-packages (from folium) (2024.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.5)
# Downloading rasterio-1.3.10-cp310-cp310-manylinux2014_x86_64.whl (21.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 59.8 MB/s eta 0:00:00
# Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Installing collected packages: snuggs, affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.3.10 snuggs-1.4.7

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
import time
import folium

# Step 1: Data Ingestion and Integration
def fetch_earthquake_data():
    url = 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_week.csv'
    data = pd.read_csv(url)
    data['geometry'] = data.apply(lambda x: Point((x.longitude, x.latitude)), axis=1)
    gdf = gpd.GeoDataFrame(data, geometry='geometry')
    return gdf

def fetch_weather_data():
    data = {
        'latitude': [37.7749, 34.0522, 40.7128],
        'longitude': [-122.4194, -118.2437, -74.0060],
        'temperature': [15, 20, 22],
        'humidity': [80, 65, 70]
    }
    df = pd.DataFrame(data)
    df['geometry'] = df.apply(lambda x: Point((x.longitude, x.latitude)), axis=1)
    return gpd.GeoDataFrame(df, geometry='geometry')

earthquake_data = fetch_earthquake_data()
weather_data = fetch_weather_data()

def enrich_data(earthquake_gdf, weather_gdf):
    enriched_gdf = gpd.sjoin(earthquake_gdf, weather_gdf, how="left", predicate='intersects')
    return enriched_gdf

enriched_data = enrich_data(earthquake_data, weather_data)

# Step 2: Convert and Drop Columns
enriched_data['time'] = pd.to_datetime(enriched_data['time'], errors='coerce')
enriched_data['updated'] = pd.to_datetime(enriched_data['updated'], errors='coerce')

columns_to_drop = ['time', 'updated', 'magType', 'net', 'id', 'place', 'type', 'status', 'locationSource', 'magSource',
                   'geometry', 'index_right', 'latitude_right', 'longitude_right', 'temperature', 'humidity']
enriched_data = enriched_data.drop(columns=columns_to_drop)

# Step 3: Feature Preparation and Imputation of Missing Values
def prepare_features(gdf):
    features = gdf[['mag', 'depth', 'nst', 'gap', 'dmin', 'rms', 'horizontalError', 'depthError', 'magError', 'magNst']]

    # Impute missing values with the mean of each column
    imputer = SimpleImputer(strategy='mean')
    features_imputed = pd.DataFrame(imputer.fit_transform(features), columns=features.columns)

    # Add the target variable
    features_imputed['disaster'] = features_imputed['mag'].apply(lambda x: 1 if x >= 5.0 else 0)

    print(f"Number of samples after feature preparation: {len(features_imputed)}")
    return features_imputed

features = prepare_features(enriched_data)

# Step 4: Train-Test Split
X = features.drop(columns=['disaster'])
y = features['disaster']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 5: Model Training
model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=42)
model.fit(X_train, y_train)

# Step 6: Model Evaluation
y_pred = model.predict(X_test)
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Accuracy Score:", accuracy_score(y_test, y_pred))

# Step 7: Ensure Imputation on Real-Time Data
# Impute missing values in enriched_data before using it in real-time monitoring
imputer = SimpleImputer(strategy='mean')
enriched_data_imputed = pd.DataFrame(imputer.fit_transform(enriched_data), columns=enriched_data.columns)

# Ensure the latitude and longitude columns exist for the real-time monitoring
enriched_data_imputed['latitude'] = earthquake_data['latitude']
enriched_data_imputed['longitude'] = earthquake_data['longitude']

# Real-Time Monitoring Simulation
def real_time_monitoring(model, incoming_data):
    for index, row in incoming_data.iterrows():
        features = pd.DataFrame([row[['mag', 'depth', 'nst', 'gap', 'dmin', 'rms', 'horizontalError', 'depthError', 'magError', 'magNst']]])
        prediction = model.predict(features)
        if prediction == 1:
            print(f"ALERT: Potential disaster detected at latitude {row['latitude']}, longitude {row['longitude']} with magnitude {row['mag']}")
        time.sleep(1)  # Simulating real-time delay

X_test_reset = X_test.reset_index(drop=True)
real_time_monitoring(model, enriched_data_imputed.loc[X_test_reset.index])

# Step 8: Visualization
enriched_data_imputed['prediction'] = model.predict(features.drop(columns=['disaster']))

def create_disaster_map(gdf):
    m = folium.Map(location=[37.7749, -122.4194], zoom_start=5)
    for _, row in gdf.iterrows():
        folium.CircleMarker(
            location=[row['latitude'], row['longitude']],
            radius=5,
            color='red' if row['prediction'] == 1 else 'green',
            fill=True,
            fill_opacity=0.6,
        ).add_to(m)
    return m

disaster_map = create_disaster_map(enriched_data_imputed)
disaster_map.save("disaster_map.html")
# Out:
# Number of samples after feature preparation: 2114
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       629
#            1       1.00      1.00      1.00         6
#
#     accuracy                           1.00       635
#    macro avg       1.00      1.00      1.00       635
# weighted avg       1.00      1.00      1.00       635
#
# Accuracy Score: 1.0
# ALERT: Potential disaster detected at latitude -5.8323, longitude 147.132 with magnitude 5.1
# ALERT: Potential disaster detected at latitude -20.7776, longitude -179.0997 with magnitude 5.0
# ALERT: Potential disaster detected at latitude -4.5404, longitude 102.0507 with magnitude 5.0

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report, accuracy_score
import time
import folium

# Step 1: Data Ingestion and Integration
def fetch_earthquake_data():
    url = 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_week.csv'
    data = pd.read_csv(url)
    data['geometry'] = data.apply(lambda x: Point((x.longitude, x.latitude)), axis=1)
    gdf = gpd.GeoDataFrame(data, geometry='geometry')
    return gdf

def fetch_weather_data():
    data = {
        'latitude': [37.7749, 34.0522, 40.7128],
        'longitude': [-122.4194, -118.2437, -74.0060],
        'temperature': [15, 20, 22],
        'humidity': [80, 65, 70]
    }
    df = pd.DataFrame(data)
    df['geometry'] = df.apply(lambda x: Point((x.longitude, x.latitude)), axis=1)
    return gpd.GeoDataFrame(df, geometry='geometry')

earthquake_data = fetch_earthquake_data()
weather_data = fetch_weather_data()

def enrich_data(earthquake_gdf, weather_gdf):
    enriched_gdf = gpd.sjoin(earthquake_gdf, weather_gdf, how="left", predicate='intersects')
    return enriched_gdf

enriched_data = enrich_data(earthquake_data, weather_data)

# Step 2: Convert and Drop Columns
enriched_data['time'] = pd.to_datetime(enriched_data['time'], errors='coerce')
enriched_data['updated'] = pd.to_datetime(enriched_data['updated'], errors='coerce')

columns_to_drop = ['time', 'updated', 'magType', 'net', 'id', 'place', 'type', 'status', 'locationSource', 'magSource',
                   'geometry', 'index_right', 'latitude_right', 'longitude_right', 'temperature', 'humidity']
enriched_data = enriched_data.drop(columns=columns_to_drop)

# Step 3: Feature Preparation (no imputation needed with HistGradientBoostingClassifier)
def prepare_features(gdf):
    features = gdf[['mag', 'depth', 'nst', 'gap', 'dmin', 'rms', 'horizontalError', 'depthError', 'magError', 'magNst']]

    # Scaling features
    scaler = MinMaxScaler()
    features_scaled = pd.DataFrame(scaler.fit_transform(features), columns=features.columns)

    # Add the target variable
    features_scaled['disaster'] = features['mag'].apply(lambda x: 1 if x >= 5.0 else 0)

    print(f"Number of samples after feature preparation: {len(features_scaled)}")
    return features_scaled

features = prepare_features(enriched_data)

# Step 4: Train-Test Split and Cross-Validation
X = features.drop(columns=['disaster'])
y = features['disaster']

# Using HistGradientBoostingClassifier (no need for imputation)
model = HistGradientBoostingClassifier(random_state=42)

# Cross-validation to evaluate model performance
cv_scores = cross_val_score(model, X, y, cv=5, scoring='accuracy')
print(f"Cross-Validation Accuracy Scores: {cv_scores}")
print(f"Mean CV Accuracy: {cv_scores.mean()}")

# Train the model on the entire dataset
model.fit(X, y)

# Step 5: Real-Time Monitoring Simulation (Optimized)
def real_time_monitoring(model, incoming_data):
    batch_size = 10  # Process data in batches instead of one at a time for efficiency
    for start in range(0, len(incoming_data), batch_size):
        end = min(start + batch_size, len(incoming_data))
        batch = incoming_data.iloc[start:end]
        features = batch[['mag', 'depth', 'nst', 'gap', 'dmin', 'rms', 'horizontalError', 'depthError', 'magError', 'magNst']]
        predictions = model.predict(features)
        for i, prediction in enumerate(predictions):
            if prediction == 1:
                print(f"ALERT: Potential disaster detected at latitude {batch.iloc[i]['latitude']}, longitude {batch.iloc[i]['longitude']} with magnitude {batch.iloc[i]['mag']}")

# Ensure the latitude and longitude columns exist for the real-time monitoring
enriched_data['latitude'] = earthquake_data['latitude']
enriched_data['longitude'] = earthquake_data['longitude']

real_time_monitoring(model, enriched_data)

# Step 6: Visualization
enriched_data['prediction'] = model.predict(features.drop(columns=['disaster']))

def create_disaster_map(gdf):
    m = folium.Map(location=[37.7749, -122.4194], zoom_start=5)
    for _, row in gdf.iterrows():
        folium.CircleMarker(
            location=[row['latitude'], row['longitude']],
            radius=5,
            color='red' if row['prediction'] == 1 else 'green',
            fill=True,
            fill_opacity=0.6,
        ).add_to(m)
    return m

disaster_map = create_disaster_map(enriched_data)
disaster_map.save("disaster_map.html")
# Out:
# Number of samples after feature preparation: 2112
# Cross-Validation Accuracy Scores: [0.9929078  0.99054374 0.99763033 0.99763033 0.99526066]
# Mean CV Accuracy: 0.9947945727314489
# ALERT: Potential disaster detected at latitude 60.7426, longitude -152.0222 with magnitude 2.8
# ALERT: Potential disaster detected at latitude 34.4043333, longitude -116.4828333 with magnitude 1.28
# ALERT: Potential disaster detected at latitude 35.01133347, longitude -97.77292633 with magnitude 1.58
# ALERT: Potential disaster detected at latitude 64.9659, longitude -147.4163 with magnitude 1.1
# ALERT: Potential disaster detected at latitude 19.3810005187988, longitude -155.252502441406 with magnitude 1.95
# ALERT: Potential disaster detected at latitude 14.7144, longitude 147.0954 with magnitude 4.8
# ALERT: Potential disaster detected at latitude 32.7465, longitude -117.3988333 with magnitude 1.37
# ALERT: Potential disaster detected at latitude 61.4587, longitude -140.4342 with magnitude 2.5
# ALERT: Potential disaster detected at latitude 35.8443336486816, longitude -121.325996398926 with magnitude 2.08
# ALERT: Potential disaster detected at latitude 61.3055, longitude -147.7041 with magnitude 0.9
# ALERT: Potential disaster detected at latitude 64.4814, longitude -149.3382 with magnitude 0.9
# ALERT: Potential disaster detected at latitude 59.4463, longitude -151.9353 with magnitude 1.9
# ALERT: Potential disaster detected at latitude 54.3575, longitude -160.1794 with magnitude 3.6
# ALERT: Potential disaster detected at latitude 17.9068333333333, longitude -66.88 with magnitude 2.01
# ALERT: Potential disaster detected at latitude 18.0016666666667, longitude -66.8803333333333 with magnitude 2.51
# ALERT: Potential disaster detected at latitude 59.6728, longitude -153.5477 with magnitude 2.0
# ALERT: Potential disaster detected at latitude 19.367166519165, longitude -155.147338867188 with magnitude 2.3
# ALERT: Potential disaster detected at latitude 60.4254, longitude -147.4232 with magnitude 1.4
# ALERT: Potential disaster detected at latitude 46.84416580200195, longitude -121.73666381835938 with magnitude 1.08000004
# ALERT: Potential disaster detected at latitude 58.7692, longitude -154.2606 with magnitude 1.8
# ALERT: Potential disaster detected at latitude 32.9646667, longitude -116.3983333 with magnitude 1.2
# ALERT: Potential disaster detected at latitude 32.985, longitude -116.3176667 with magnitude 1.43
# ALERT: Potential disaster detected at latitude 19.5813331604004, longitude -155.611663818359 with magnitude 2.6500001
# ALERT: Potential disaster detected at latitude 36.6710014343262, longitude -121.342498779297 with magnitude 1.75
# ALERT: Potential disaster detected at latitude 35.0851667, longitude -119.0913333 with magnitude 1.23
# ALERT: Potential disaster detected at latitude 60.0935, longitude -139.7556 with magnitude 2.0
# ALERT: Potential disaster detected at latitude 34.416, longitude -117.703 with magnitude 1.12
# ALERT: Potential disaster detected at latitude 61.5103, longitude -152.2011 with magnitude 1.7
# ALERT: Potential disaster detected at latitude 61.6894, longitude -148.1351 with magnitude 0.9
# ALERT: Potential disaster detected at latitude 33.654, longitude -117.0106667 with magnitude 1.47
# ALERT: Potential disaster detected at latitude 35.9485, longitude -117.6873333 with magnitude 1.55
# ALERT: Potential disaster detected at latitude 35.3233333, longitude -118.5368333 with magnitude 1.54
# ALERT: Potential disaster detected at latitude -23.6063, longitude -67.1043 with magnitude 4.4
# ALERT: Potential disaster detected at latitude 61.03, longitude -150.2963 with magnitude 1.9
# ALERT: Potential disaster detected at latitude 37.4311, longitude -115.5413 with magnitude 1.2
# ALERT: Potential disaster detected at latitude 38.7921676635742, longitude -122.777336120605 with magnitude 0.93
# ALERT: Potential disaster detected at latitude 38.7900009155273, longitude -122.77766418457 with magnitude 2.22
# ALERT: Potential disaster detected at latitude 19.386999130249, longitude -155.241668701172 with magnitude 1.88999999
# ALERT: Potential disaster detected at latitude 19.6591663360596, longitude -155.045669555664 with magnitude 2.68
# ALERT: Potential disaster detected at latitude 61.653, longitude -146.6184 with magnitude 1.5
# ALERT: Potential disaster detected at latitude 61.0783, longitude -152.3237 with magnitude 0.9
# ALERT: Potential disaster detected at latitude 47.28383333333333, longitude -122.06216666666668 with magnitude 1.5
# ALERT: Potential disaster detected at latitude 38.6656, longitude -118.5642 with magnitude 2.2
# ALERT: Potential disaster detected at latitude 31.591, longitude -104.55 with magnitude 1.5
# ALERT: Potential disaster detected at latitude 10.6027, longitude -86.4385 with magnitude 4.8
# ALERT: Potential disaster detected at latitude 62.9614, longitude -150.5251 with magnitude 1.2
# ALERT: Potential disaster detected at latitude -19.5953, longitude -177.5105 with magnitude 4.4
# ALERT: Potential disaster detected at latitude 35.3238333, longitude -118.5333333 with magnitude 1.37
# ALERT: Potential disaster detected at latitude 61.375, longitude -150.2374 with magnitude 1.4
# ALERT: Potential disaster detected at latitude
with magnitude 1.6
# ALERT: Potential disaster detected at latitude 31.653, longitude -104.294 with magnitude 1.8
# ALERT: Potential disaster detected at latitude 44.4063333333333, longitude -115.209333333333 with magnitude 2.29
# ALERT: Potential disaster detected at latitude 38.837833404541, longitude -122.808166503906 with magnitude 1.0
# ALERT: Potential disaster detected at latitude 62.1916, longitude -149.4203 with magnitude 2.1
# ALERT: Potential disaster detected at latitude 38.6707, longitude -118.5639 with magnitude 1.3
# ALERT: Potential disaster detected at latitude 38.0001678466797, longitude -122.236999511719 with magnitude 1.85
# ALERT: Potential disaster detected at latitude 63.1185, longitude -150.9681 with magnitude 1.1
# ALERT: Potential disaster detected at latitude 38.7958335876465, longitude -122.729835510254 with magnitude 1.37
# ALERT: Potential disaster detected at latitude 61.7456, longitude -150.9197 with magnitude 1.8
# ALERT: Potential disaster detected at latitude -24.3495, longitude -67.1654 with magnitude 4.2
# ALERT: Potential disaster detected at latitude 31.657, longitude -104.294 with magnitude 1.6
# ALERT: Potential disaster detected at latitude 52.929, longitude 160.6823 with magnitude 4.7
# ALERT: Potential disaster detected at latitude 38.6807, longitude -118.559 with magnitude 1.9
# ALERT: Potential disaster detected at latitude 59.5399, longitude -153.0618 with magnitude 1.5
# ALERT: Potential disaster detected at latitude 32.9881667, longitude -116.328 with magnitude 2.77
# ALERT: Potential disaster detected at latitude 38.684, longitude -118.5554 with magnitude 3.4
# ALERT: Potential disaster detected at latitude 38.6856, longitude -118.5691 with magnitude 2.4
# ALERT: Potential disaster detected at latitude 38.6804, longitude -118.5554 with magnitude 3.3
# ALERT: Potential disaster detected at latitude -23.4312, longitude -179.7837 with magnitude 4.9
# ALERT: Potential disaster detected at latitude 62.1414, longitude -150.2129 with magnitude 0.9
# ALERT: Potential disaster detected at latitude 62.5677, longitude -152.1555 with magnitude 1.4
# ALERT: Potential disaster detected at latitude 62.3598, longitude -147.8338 with magnitude 1.9
# ALERT: Potential disaster detected at latitude 38.8156661987305, longitude -122.794998168945 with magnitude 1.72
# ALERT: Potential disaster detected at latitude 38.8153343200684, longitude -122.794998168945 with magnitude 2.23
# ALERT: Potential disaster detected at latitude 38.8261680603027, longitude -122.803169250488 with magnitude 1.04
# ALERT: Potential disaster detected at latitude 54.5713, longitude -117.2549 with magnitude 4.2
# ALERT: Potential disaster detected at latitude 64.6436, longitude -149.6854 with magnitude 1.2
# ALERT: Potential disaster detected at latitude 61.4236, longitude -145.0343 with magnitude 1.3
# ALERT: Potential disaster detected at latitude 38.6683, longitude -118.5584 with magnitude 1.8
# ALERT: Potential disaster detected at latitude 60.2193, longitude -151.0331 with magnitude 1.4
# ALERT: Potential disaster detected at latitude 37.5284, longitude -117.1891 with magnitude 1.4
# ALERT: Potential disaster detected at latitude 35.8986663818359, longitude -121.238670349121 with magnitude 2.02
# ALERT: Potential disaster detected at latitude 19.4096660614014, longitude -155.3056640625 with magnitude 2.21000004
# ALERT: Potential disaster detected at latitude -6.9122, longitude 125.9069 with magnitude 4.3
# ALERT: Potential disaster detected at latitude 38.7905006408691, longitude -122.767997741699 with magnitude 1.34
# ALERT: Potential disaster detected at latitude 61.4528, longitude -150.6747 with magnitude 1.0
# ALERT: Potential disaster detected at latitude 62.2994, longitude -148.8042 with magnitude 1.1
# ALERT: Potential disaster detected at latitude 40.2220001220703, longitude -122.826332092285 with magnitude 2.01
# ALERT: Potential disaster detected at latitude 32.9763333, longitude -116.2776667 with magnitude 0.98
# ALERT: Potential disaster detected at latitude 61.2621, longitude -147.0173 with magnitude 1.8
# ALERT: Potential disaster detected at latitude 33.1528333, longitude -116.0491667 with magnitude 1.39
# ALERT: Potential disaster detected at latitude 62.3792, longitude -150.2777 with magnitude 1.2
# ALERT: Potential disaster detected at latitude 35.1116667, longitude -119.0431667 with magnitude 1.81
# ALERT: Potential disaster detected at latitude 35.8301658630371, longitude -120.552169799805 with magnitude 1.03
# ALERT: Potential disaster detected at latitude 38.7826652526855, longitude -122.755500793457 with magnitude 0.98
# ALERT: Potential disaster detected at latitude 59.8199, longitude -153.4283 with magnitude 1.8
# ALERT: Potential disaster detected at latitude 19.4106674194336, longitude -155.262664794922 with magnitude 1.98
# ALERT: Potential disaster detected at latitude 33.8741684, longitude -116.8779984 with magnitude 1.1
# ALERT: Potential disaster detected at latitude 31.673, longitude -104.182 with magnitude 1.8
# ALERT: Potential disaster detected at latitude 32.359, longitude -102.089 with magnitude 1.0
# ALERT: Potential disaster detected at latitude 63.1459, longitude -150.0575 with magnitude 1.0
# ALERT: Potential disaster detected at latitude 38.6816, longitude -118.5597 with magnitude 2.2
# ALERT: Potential disaster detected at latitude 38.6792, longitude -118.5623 with magnitude 2.5
# ALERT: Potential disaster detected at latitude 46.9961666666667, longitude -114.1855 with magnitude 1.05
# ALERT: Potential disaster detected at latitude 31.49, longitude -115.6156667 with magnitude 2.16
# ALERT: Potential disaster detected at latitude 63.5263, longitude -150.8968 with magnitude 1.3
# ALERT: Potential disaster detected at latitude 32.9828333, longitude -115.5685 with magnitude 1.28
# ALERT: Potential disaster detected at latitude 46.83283333333333, longitude -121.94016666666668 with magnitude 0.94
# ALERT: Potential disaster detected at latitude 37.3868333333333, longitude -119.978 with magnitude 2.21
# ALERT: Potential disaster detected at latitude 37.4088333333333, longitude -119.9915 with magnitude 2.4
# ALERT: Potential disaster detected at latitude 19.3815002441406, longitude -155.234664916992 with magnitude 1.94
# ALERT: Potential disaster detected at latitude -32.3093, longitude 150.6915 with magnitude 4.4
# ALERT: Potential disaster detected at latitude 38.6839, longitude -118.564 with magnitude 1.9
# ALERT: Potential disaster detected at latitude 35.3566667, longitude -117.9056667 with magnitude 1.47
# ALERT: Potential disaster detected at latitude 34.5843333333333, longitude -85.984 with magnitude 2.26
# ALERT: Potential disaster detected at latitude 36.0844993591309, longitude -120.160331726074 with magnitude 2.07
# ALERT: Potential disaster detected at latitude 19.158332824707, longitude -155.457504272461 with magnitude 1.95000005
# ALERT: Potential disaster detected at latitude 35.181, longitude -117.256 with magnitude 1.76
# ALERT: Potential disaster detected at latitude 38.6818, longitude -118.558 with magnitude 1.6
# ALERT: Potential disaster detected at latitude 31.678, longitude -104.352 with magnitude 1.5
# ALERT: Potential disaster detected at latitude 38.6773, longitude -118.5631 with magnitude 1.4
# ALERT: Potential disaster detected at latitude 19.1626663208008, longitude -155.488494873047 with magnitude 2.1500001
# ALERT: Potential disaster detected at latitude 38.6889, longitude -118.5599 with magnitude 2.0
# ALERT: Potential disaster detected at latitude 38.6729, longitude -118.5626 with magnitude 2.7
# ALERT: Potential disaster detected at latitude 38.6734, longitude -118.5579 with magnitude 3.3
# ALERT: Potential disaster detected at latitude 31.909, longitude -101.761 with magnitude 1.3
# ALERT: Potential disaster detected at latitude 63.5493, longitude -149.6574 with magnitude 1.1
# ALERT: Potential disaster detected at latitude -6.658, longitude 105.1034 with magnitude 4.8
# ALERT: Potential disaster detected at latitude 38.0316666666667, longitude -118.778833333333 with magnitude 1.69
# ALERT: Potential disaster detected at latitude 56.862, longitude -158.149333333333 with magnitude 1.27
# ALERT: Potential disaster detected at latitude 56.8658333333333, longitude -158.115 with magnitude 0.98
# ALERT: Potential disaster detected at latitude 19.3854999542236, longitude -155.158828735352 with magnitude 1.86
# ALERT: Potential disaster detected at latitude 38.8091659545898, longitude -122.820663452148 with magnitude 2.01
# ALERT: Potential disaster detected at latitude 33.96, longitude -116.9646667 with magnitude 2.04
# ALERT: Potential disaster detected at latitude 18.3598333333333, longitude -65.899 with magnitude 3.38
# ALERT: Potential disaster detected at latitude -10.3046, longitude 123.6737 with magnitude 4.5
# ALERT: Potential disaster detected at latitude 12.7336, longitude 124.763 with magnitude 5.7
# ALERT: Potential disaster detected at latitude 40.3221666666667, longitude -124.359166666667 with magnitude 1.55
# ALERT: Potential disaster detected at latitude 35.0105, longitude -119.1331667 with magnitude 1.25
# ALERT: Potential disaster detected at latitude 19.1951675415039, longitude -155.367004394531 with magnitude 1.94000006
# ALERT: Potential disaster detected at latitude 38.5066666666667, longitude -112.8745 with magnitude 0.89
# ALERT: Potential disaster detected at latitude 31.694, longitude -104.465 with magnitude 1.5
# ALERT: Potential disaster detected at latitude 36.4176667, longitude -117.9201667 with magnitude 1.54
# ALERT: Potential disaster detected at latitude 38.8363342285156, longitude -122.801170349121 with magnitude 1.46
# ALERT: Potential disaster detected at latitude 28.765, longitude -98.271 with magnitude 1.5
# ALERT: Potential disaster detected at latitude 39.0493333333333, longitude -123.126666666667 with magnitude 1.28
# ALERT: Potential disaster detected at latitude 35.5465, longitude -96.7445 with magnitude 1.05
# ALERT: Potential disaster detected at latitude 35.9486667, longitude -117.6685 with magnitude 1.06
# ALERT: Potential disaster detected at latitude 34.5035, longitude -116.4968333 with magnitude 1.11
# ALERT: Potential disaster detected at latitude 19.3808326721191, longitude -155.25 with magnitude 1.85
# ALERT: Potential disaster detected at latitude 33.5651667, longitude -118.0188333 with magnitude 1.7
# ALERT: Potential disaster detected at latitude 38.8160018920898, longitude -122.818832397461 with magnitude 0.94
# ALERT: Potential disaster detected at latitude 35.9475, longitude -117.6716667 with magnitude 0.96
# ALERT: Potential disaster detected at latitude 35.27233333, longitude -98.04016667 with magnitude 1.92
# ALERT: Potential disaster detected at latitude 35.9693333, longitude -117.6573333 with magnitude 2.25
# ALERT: Potential disaster detected at latitude 31.661, longitude -104.467 with magnitude 1.6
# ALERT: Potential disaster detected at latitude 19.3845, longitude -155.249 with magnitude 2.1
# ALERT: Potential disaster detected at latitude 38.7918319702148, longitude -122.777496337891 with magnitude 1.32
# ALERT: Potential disaster detected at latitude 35.34866667, longitude -97.95416667 with magnitude 0.92
# ALERT: Potential disaster detected at latitude 33.241, longitude -116.0378333 with magnitude 1.46
# ALERT: Potential disaster detected at latitude 38.8363342285156, longitude -122.801002502441 with magnitude 2.63
# ALERT: Potential disaster detected at latitude 19.1720008850098, longitude -155.496673583984 with magnitude 2.38000011
# ALERT: Potential disaster detected at latitude 19.1571666666667, longitude -155.5085 with magnitude 1.73
# ALERT: Potential disaster detected at latitude 35.767, longitude -117.5735 with magnitude 1.15
# ALERT: Potential disaster detected at latitude -37.0664, longitude -73.9529 with magnitude 5.2
# ALERT: Potential disaster detected at latitude 19.099, longitude -64.765 with magnitude 3.8
